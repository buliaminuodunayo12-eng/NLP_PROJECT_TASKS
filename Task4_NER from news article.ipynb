# %%
# !pip install -q kagglehub spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_trf
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 81.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting en-core-web-trf==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.8.0/en_core_web_trf-3.8.0-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 3.4 MB/s eta 0:00:00
# Collecting spacy-curated-transformers<1.0.0,>=0.2.2 (from en-core-web-trf==3.8.0)
#   Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.8.0+cu126)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.12/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2024.11.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.0.2)
# Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.9/237.9 kB 3.8 MB/s eta 0:00:00
# Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (734 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.0/734.0 kB 19.6 MB/s eta 0:00:00
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en-core-web-trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.8.0 spacy-curated-transformers-0.3.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import kagglehub, os, pandas as pd


path = kagglehub.dataset_download("clmentbisaillon/fake-and-real-news-dataset")
print("Dataset files are in:", path)
print(os.listdir(path))


fake = pd.read_csv(os.path.join(path, "Fake.csv"))
true = pd.read_csv(os.path.join(path, "True.csv"))


fake["label"] = 0   # Fake
true["label"] = 1   # Real
df = pd.concat([fake, true], ignore_index=True)

print(df.shape)
df.head(2)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/clmentbisaillon/fake-and-real-news-dataset?dataset_version_number=1...
# 100%|██████████| 41.0M/41.0M [00:00<00:00, 148MB/s]
# Extracting files...
# Dataset files are in: /root/.cache/kagglehub/datasets/clmentbisaillon/fake-and-real-news-dataset/versions/1
# ['True.csv', 'Fake.csv']
# (44898, 5)
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0

# %%
import spacy


nlp_sm = spacy.load("en_core_web_sm")


nlp_trf = spacy.load("en_core_web_trf")

# %%
sample_text = df.loc[10, "text"]
print(sample_text[:500], "...")


doc_sm = nlp_sm(sample_text)
print("\nEntities (small model):")
for ent in doc_sm.ents:
    print(ent.text, "->", ent.label_)


doc_trf = nlp_trf(sample_text)
print("\nEntities (transformer model):")
for ent in doc_trf.ents:
    print(ent.text, "->", ent.label_)
# Out:
# A centerpiece of Donald Trump s campaign, and now his presidency, has been his white supremacist ways. That is why so many of the public feuds he gets into involve people of color. One of his favorite targets, is, of course, the players in the National Football League who dare to exercise their First Amendment rights by kneeling during the national anthem in protest of racist police brutality. Well, there is one person who has figured out that racism is bad for business, even if it did get the o ...
#
# Entities (small model):
# Donald Trump -> PERSON
# One -> CARDINAL
# the National Football League -> ORG
# First Amendment -> LAW
# one -> CARDINAL
# Papa John s.This -> PERSON
# doesn -> PERSON
# Papa John Schnatter -> PERSON
# Papa John's -> PERSON
# John Schnatter -> PERSON
# weeks -> DATE
# NFL -> ORG
# AP Business News -> ORG
# December 21 -> DATE
# 2017The -> CARDINAL
# boycotts -> GPE
# NFL -> ORG
# America -> GPE
# the Statue of Liberty -> FAC
# Trump -> PERSON
# Schnatter -> PERSON
# Rob Kim/Getty Images -> PERSON
#
# Entities (transformer model):
# Donald Trump s -> PERSON
# One -> CARDINAL
# the National Football League -> ORG
# First Amendment -> LAW
# Papa John s. -> ORG
# Papa John Schnatter -> PERSON
# Papa John's -> ORG
# John Schnatter -> PERSON
# weeks -> DATE
# NFL -> ORG
# AP Business News -> ORG
# December 21, 2017The -> DATE
# NFL -> ORG
# America -> GPE
# the Statue of Liberty -> WORK_OF_ART
# Trump -> PERSON
# Schnatter -> PERSON
# Rob Kim -> PERSON

# %%
from spacy import displacy


displacy.render(doc_trf, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A centerpiece of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  campaign, and now his presidency, has been his white supremacist ways. That is why so many of the public feuds he gets into involve people of color.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of his favorite targets, is, of course, the players in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the National Football League
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  who dare to exercise their
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First Amendment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  rights by kneeling during the national anthem in protest of racist police brutality. Well, there is one person who has figured out that racism is bad for business, even if it did get the orange overlord elected: The founder of the pizza chain
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Papa John s.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# This is a man who has never been on the right side of history on any number of issues, and plus his pizza sucks. But, when he decided to complain about the players protesting, his sales really dropped. Turns out racism doesn t pay, and we all know that corporations are all about the bottom line. Therefore,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Papa John Schnatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will no longer be CEO of the hack pizza chain.BREAKING:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Papa John's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Schnatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to step down as CEO; announcement comes
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after he criticized
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  over protests.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AP Business News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (@APBusiness)
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 21, 2017The
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  thing is, while people are certainly allowed to have political opinions, they have to realize that those opinions can often come with dire consequences   especially if one is in the business of trying to garner sales and support from any and all people, which one would presume is the goal of all CEO s. No one knows whether or not the pressure from his shareholders, the public outcry or boycotts, or even the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  itself had anything to do with his stepping down. As of right now, all we know is that he will be gone, and perhaps the future CEO will run a company that is inclusive of the diverse fabric that we call
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . After all, the guiding symbol of this nation will always be
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Statue of Liberty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , and bigots like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schnatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are the past. The rest of us are the future. We just have to survive the present to get there.Featured image via
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rob Kim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /Getty Images</div></span>

# %%
for i in range(5):
    text = df[df["label"]==1].iloc[i]["text"]
    doc = nlp_sm(text)
    print(f"\n🔹 Article {i+1}")
    print([ (ent.text, ent.label_) for ent in doc.ents ])
# Out:
# 🔹 Article 1
# [('WASHINGTON', 'GPE'), ('Reuters', 'ORG'), ('Republican', 'NORP'), ('the U.S. Congress', 'ORG'), ('this month', 'DATE'), ('Sunday', 'DATE'), ('2018', 'DATE'), ('Republicans', 'NORP'), ('U.S.', 'GPE'), ('Mark Meadows', 'PERSON'), ('CBS', 'ORG'), ('Face the Nation', 'WORK_OF_ART'), ('January', 'DATE'), ('the holidays on', 'DATE'), ('Wednesday', 'DATE'), ('November', 'DATE'), ('Republicans', 'NORP'), ('Congress', 'ORG'), ('Donald Trump', 'PERSON'), ('Republicans', 'NORP'), ('Democrats', 'NORP'), ('Trump', 'ORG'), ('about 7 percent', 'PERCENT'), ('House', 'ORG'), ('Democrats', 'NORP'), ('10 to 11 percent', 'PERCENT'), ('Republicans', 'NORP'), ('late December', 'DATE'), ('about $1.5 trillion', 'MONEY'), ('10 years', 'DATE'), ('$20 trillion', 'MONEY'), ('Mark', 'PERSON'), ('Democratic', 'NORP'), ('U.S.', 'GPE'), ('Joseph Crowley', 'PERSON'), ('CBS', 'ORG'), ('Crowley', 'ORG'), ('Republican', 'NORP'), ('United States', 'GPE'), ('$1.5 trillion', 'MONEY'), ('the House of Representatives', 'ORG'), ('Crowley', 'PERSON'), ('Republicans', 'NORP'), ('U.S.', 'GPE'), ('more than 30 years', 'DATE'), ('House', 'ORG'), ('Paul Ryan', 'PERSON'), ('Meadows', 'ORG'), ('Republican', 'NORP'), ('2018', 'DATE'), ('Republican', 'NORP'), ('Medicare', 'ORG'), ('Medicaid', 'ORG'), ('Washington', 'GPE'), ('Democrats', 'NORP'), ('Ryan', 'PERSON'), ('early December', 'DATE'), ('Republicans', 'NORP'), ('House', 'ORG'), ('Republicans', 'NORP'), ('Senate', 'ORG'), ('Democrats', 'NORP'), ('Democrats', 'NORP'), ('Senate', 'ORG'), ('Republicans', 'NORP'), ('September', 'DATE'), ('March 2018', 'DATE'), ('the Deferred Action for Childhood Arrivals', 'ORG'), ('Mexican', 'NORP'), ('Debbie Dingell', 'PERSON'), ('CBS', 'ORG'), ('DACA', 'ORG'), ('Wednesday', 'DATE'), ('Trump', 'ORG'), ('a weekend', 'DATE'), ('Trump', 'ORG'), ('Republican', 'NORP'), ('Jan. 6 and 7', 'DATE'), ('the White House', 'ORG'), ('Trump', 'PERSON'), ('Sunday', 'DATE'), ('Florida', 'GPE'), ('Republican', 'NORP'), ('Rick Scott', 'PERSON'), ('House', 'ORG'), ('$81 billion', 'MONEY'), ('Florida', 'GPE'), ('Texas', 'GPE'), ('Puerto Rico', 'GPE'), ('California', 'GPE'), ('$44 billion', 'MONEY'), ('Trump', 'PERSON'), ('Senate', 'ORG')]
#
# 🔹 Article 2
# [('WASHINGTON', 'GPE'), ('Reuters', 'ORG'), ('first', 'ORDINAL'), ('U.S.', 'GPE'), ('Monday', 'DATE'), ('Pentagon', 'ORG'), ('Friday', 'DATE'), ('Donald Trump', 'PERSON'), ('Two', 'CARDINAL'), ('one', 'CARDINAL'), ('Washington', 'GPE'), ('one', 'CARDINAL'), ('Virginia', 'GPE'), ('last week', 'DATE'), ('Jan. 1', 'DATE'), ('Justice Department', 'ORG'), ('The Department of Defense', 'ORG'), ('the coming weeks', 'DATE'), ('DOD’s', 'ORG'), ('District Court', 'ORG'), ('September', 'DATE'), ('Pentagon', 'ORG'), ('Trump', 'ORG'), ('The Defense Department', 'ORG'), ('Feb. 21', 'DATE'), ('Trump', 'ORG'), ('Supreme Court', 'ORG'), ('Pentagon', 'ORG'), ('Heather Babb', 'PERSON'), ('the Department of Defense', 'ORG'), ('Jan. 1', 'DATE'), ('Jennifer Levi', 'PERSON'), ('lesbian', 'PERSON'), ('Levi', 'PERSON'), ('the American Civil Liberties Union', 'ORG'), ('Trump', 'ORG'), ('July', 'DATE'), ('Democratic', 'NORP'), ('Barack Obama', 'PERSON'), ('Trump', 'PERSON'), ('Twitter', 'PERSON'), ('Four', 'CARDINAL'), ('Baltimore', 'GPE'), ('Washington', 'GPE'), ('D.C.', 'GPE'), ('Seattle', 'GPE'), ('Riverside', 'GPE'), ('California', 'GPE'), ('Trump', 'ORG'), ('Republican', 'NORP'), ('the U.S. Constitution', 'LAW'), ('Pentagon', 'ORG'), ('Dec. 8', 'DATE'), ('Jan. 1', 'DATE'), ('Trump', 'PERSON'), ('thousands', 'CARDINAL'), ('Obama', 'PERSON'), ('July 1, 2017', 'DATE'), ('Trump', 'ORG'), ('James Mattis', 'PERSON'), ('Jan. 1, 2018', 'DATE'), ('Trump', 'ORG'), ('October', 'DATE'), ('Obama-era', 'DATE'), ('February', 'DATE'), ('Trump', 'ORG'), ('Obama', 'PERSON')]
#
# 🔹 Article 3
# [('WASHINGTON', 'GPE'), ('Reuters', 'ORG'), ('Russia', 'GPE'), ('Trump’s', 'PERSON'), ('2016', 'DATE'), ('2018', 'DATE'), ('Trump', 'ORG'), ('Republican', 'NORP'), ('Republican', 'NORP'), ('Sunday', 'DATE'), ('Lindsey Graham', 'PERSON'), ('Senate', 'ORG'), ('Department of Justice Special Counsel', 'ORG'), ('Robert Mueller', 'PERSON'), ('Russia', 'GPE'), ('Graham', 'PERSON'), ('CBS’s Face the Nation', 'ORG'), ('Mueller', 'PERSON'), ('Russia', 'GPE'), ('Trump', 'ORG'), ('the White House', 'ORG'), ('Trump', 'ORG'), ('January', 'DATE'), ('Trump', 'ORG'), ('his second year', 'DATE'), ('Trump', 'ORG'), ('recent weeks', 'DATE'), ('Mueller', 'ORG'), ('Republican', 'NORP'), ('an interview last week', 'DATE'), ('the New York Times', 'ORG'), ('Mueller', 'PERSON'), ('Russia', 'GPE'), ('Trump', 'ORG'), ('Washington', 'GPE'), ('Three', 'CARDINAL'), ('Senate', 'ORG'), ('the House of Representatives', 'ORG'), ('Mueller', 'PERSON'), ('May', 'DATE'), ('the U.S. Federal Bureau of Investigation (FBI', 'ORG'), ('Trump', 'ORG'), ('Trump', 'PERSON'), ('Russia', 'GPE'), ('Kremlin', 'ORG'), ('Graham', 'PERSON'), ('FBI', 'ORG'), ('Trump', 'ORG'), ('Russia', 'GPE'), ('British', 'NORP'), ('Christopher Steele', 'PERSON'), ('Trump', 'ORG'), ('Republicans', 'NORP'), ('Mueller', 'ORG'), ('Saturday', 'DATE'), ('the New York Times', 'ORG'), ('FBI', 'ORG'), ('Trump', 'ORG'), ('George Papadopoulos', 'PERSON'), ('Australian', 'NORP'), ('Russia', 'GPE'), ('Trump', 'ORG'), ('Hillary Clinton', 'PERSON'), ('the Department of Justice', 'ORG'), ('Graham', 'PERSON'), ('Russia', 'GPE')]
#
# 🔹 Article 4
# [('WASHINGTON', 'GPE'), ('Reuters', 'ORG'), ('George Papadopoulos', 'PERSON'), ('Australian', 'NORP'), ('May 2016', 'DATE'), ('Russia', 'GPE'), ('Democratic', 'NORP'), ('Hillary Clinton', 'PERSON'), ('the New York Times', 'ORG'), ('Saturday', 'DATE'), ('Papadopoulos', 'PERSON'), ('Alexander Downer', 'PERSON'), ('London', 'GPE'), ('FBI', 'ORG'), ('Moscow', 'GPE'), ('Trump', 'ORG'), ('Times', 'ORG'), ('Two months', 'DATE'), ('Australian', 'NORP'), ('Papadopoulos', 'PERSON'), ('American', 'NORP'), ('Democratic', 'NORP'), ('four', 'CARDINAL'), ('U.S.', 'GPE'), ('Australians', 'NORP'), ('the Federal Bureau of Investigation', 'ORG'), ('British', 'NORP'), ('Dutch', 'NORP'), ('Times', 'ORG'), ('Papadopoulos', 'PERSON'), ('Chicago', 'GPE'), ('Oct. 30', 'DATE'), ('FBI', 'ORG'), ('Russian', 'NORP'), ('first', 'ORDINAL'), ('Trump', 'ORG'), ('Russia', 'GPE'), ('The White House', 'ORG'), ('The New York Times', 'ORG'), ('Papadopoulos', 'PERSON'), ('Donald Trump', 'PERSON'), ('Egyptian', 'NORP'), ('Abdel Fattah al-Sisi', 'PERSON'), ('Trump', 'ORG'), ('first', 'ORDINAL'), ('April 2016', 'DATE'), ('Robert Mueller', 'PERSON'), ('Trump’s White House', 'PERSON'), ('almost a year ago', 'DATE'), ('Trump', 'ORG'), ('Mueller', 'ORG'), ('Republican', 'NORP'), ('Papadopoulos', 'PERSON'), ('Reuters', 'ORG'), ('Mueller', 'ORG'), ('Trump’s', 'PERSON'), ('White House', 'ORG'), ('Ty Cobb', 'PERSON'), ('the New York Times', 'ORG'), ('Mueller', 'ORG'), ('four', 'CARDINAL'), ('Trump', 'ORG'), ('Papadopoulos', 'PERSON'), ('Russia', 'GPE'), ('U.S.', 'GPE'), ('Trump', 'ORG'), ('Moscow', 'GPE')]
#
# 🔹 Article 5
# [('SEATTLE', 'GPE'), ('Reuters', 'ORG'), ('Donald Trump', 'PERSON'), ('the U.S. Postal Service', 'ORG'), ('Friday', 'DATE'), ('Amazon', 'ORG'), ('the United States Post Office', 'ORG'), ('billions of dollars', 'MONEY'), ('Amazon', 'ORG'), ('Amazon', 'ORG'), ('Post Office', 'ORG'), ('Trump', 'PERSON'), ('Twitter', 'PERSON'), ('the Postal Service', 'ORG'), ('tens of millions', 'MONEY'), ('the holiday season', 'DATE'), ('The U.S. Postal Service', 'ORG'), ('Package', 'ORG'), ('first', 'ORDINAL'), ('the Postal Regulatory Commission', 'ORG'), ('almost 2 percent', 'PERCENT'), ('November', 'DATE'), ('Amazon', 'ORG'), ('Jeff Bezos', 'PERSON'), ('Bloomberg News', 'ORG'), ('Bezos', 'PERSON'), ('The Washington Post', 'ORG'), ('Trump', 'ORG'), ('the past year', 'DATE'), ('Trump', 'ORG'), ('Amazon Washington Post', 'ORG'), ('Amazon', 'ORG'), ('American', 'NORP'), ('January', 'DATE'), ('Daniel Ives', 'PERSON'), ('GBH Insights', 'ORG'), ('Trump', 'ORG'), ('Amazon', 'ORG'), ('Amazon', 'ORG'), ('Amazon', 'ORG'), ('2015', 'DATE'), ('$11.5 billion', 'MONEY'), ('46 percent', 'PERCENT'), ('that year', 'DATE'), ('Amazon', 'ORG'), ('0.86 percent', 'PERCENT'), ('1,175.90', 'MONEY'), ('early afternoon', 'TIME'), ('U.S.', 'GPE'), ('Friday', 'DATE'), ('Satish Jindel', 'NORP'), ('ShipMatrix Inc', 'ORG'), ('the Postal Service', 'ORG'), ('United Parcel Service Inc', 'ORG'), ('FedEx Corp', 'ORG'), ('the United States', 'GPE'), ('UPS', 'ORG'), ('FedEx', 'GPE'), ('The Postal Service', 'ORG'), ('about 62 percent', 'PERCENT'), ('Amazon', 'ORG'), ('about 3.5 to 4 million', 'CARDINAL'), ('the current peak', 'DATE'), ('year-end', 'DATE'), ('Jindel', 'NORP'), ('Seattle', 'GPE'), ('Amazon', 'ORG'), ('Amazon', 'ORG'), ('2', 'CARDINAL'), ('UPS', 'ORG'), ('21 percent', 'PERCENT'), ('FedEx', 'GPE'), ('third', 'ORDINAL'), ('8 percent', 'PERCENT'), ('Trump', 'PERSON'), ('Postal Service', 'ORG'), ('UPS', 'ORG'), ('Steve Gaut', 'PERSON'), ('UPS', 'ORG'), ('the Postal Regulatory Commission', 'ORG'), ('Amazon', 'ORG'), ('the White House', 'ORG'), ('the U.S. Postal Service', 'ORG'), ('FedEx', 'GPE'), ('Trump', 'ORG'), ('annual', 'DATE'), ('the Postal Service', 'ORG'), ('$2.74 billion', 'MONEY'), ('this year', 'DATE'), ('$61.86 billion', 'MONEY'), ('the Postal Service’s', 'ORG'), ('first', 'ORDINAL'), ('44 percent', 'PERCENT'), ('2014', 'DATE'), ('$19.5 billion', 'MONEY'), ('the fiscal year ended Sept. 30, 2017', 'DATE'), ('about $2 billion', 'MONEY'), ('April 2016', 'DATE'), ('Government Accountability Office', 'ORG'), ('February', 'DATE'), ('$73.4 billion', 'MONEY'), ('The Postal Service', 'ORG'), ('the Postal Service', 'ORG'), ('only 5.5 percent', 'PERCENT'), ('28 percent', 'PERCENT')]

# %%
import re

def regex_rule_based_entities(text):
    results = {}


    results["dates"] = re.findall(r"\b(?:\d{1,2}\/\d{1,2}\/\d{2,4}|[A-Z][a-z]+ \d{4})\b", text)


    results["money"] = re.findall(r"[$€£]\s?\d+(?:,\d{3})*(?:\.\d{2})?", text)


    results["emails"] = re.findall(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}", text)


    results["percentages"] = re.findall(r"\d+(\.\d+)?\s?%", text)


    results["capitalized"] = re.findall(r"\b(?:[A-Z][a-z]+(?:\s+[A-Z][a-z]+)*)\b", text)

    return results



sample_text = df.loc[150, "text"]
print("Sample text (preview):\n", sample_text[:300], "...\n")

entities = regex_rule_based_entities(sample_text)
print("🔹 Rule-based Entities (Regex):")
for k, v in entities.items():
    print(f"{k}: {v[:10]}")
# Out:
# Sample text (preview):
#  When Donald Trump allowed popular Nazi blog The Gateway Pundit to have a correspondent show up at the White House, many questioned that decision   but if The Donald was going for comic relief, we re forced to admit that the inclusion of Lucian Wintrich is a complete success.Recently, the White House ...
#
# 🔹 Rule-based Entities (Regex):
# dates: []
# money: []
# emails: []
# percentages: []
# capitalized: ['When Donald Trump', 'Nazi', 'The Gateway Pundit', 'White House', 'The Donald', 'Lucian Wintrich', 'Recently', 'White House', 'Twitter', 'Krang']
